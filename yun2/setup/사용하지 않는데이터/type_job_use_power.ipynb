# %%
# 필요 라이브러리 로드
from matplotlib import font_manager, rc
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import platform

#그래프에서 마이너스 기호가 표시되게 하는 설정입니다.
plt.rcParams['axes.unicode_minus'] == False
# Out:
# False

# %%
path1 = 'data/광주광역시_용도별_월사용량/계약종별 전력사용량 월별_2021.01~06.xls'
path2 = 'data/광주광역시_용도별_월사용량/계약종별 전력사용량 월별_2021.07~12.xls'
path3 = 'data/광주광역시_용도별_월사용량/계약종별 전력사용량 월별_2022.01~06.xls'
path4 = 'data/광주광역시_용도별_월사용량/계약종별 전력사용량 월별_2022.07~12.xls'
power_jobtype_2021_01 = pd.read_excel(path1)
power_jobtype_2021_07 = pd.read_excel(path2)
power_jobtype_2022_01 = pd.read_excel(path3)
power_jobtype_2022_07 = pd.read_excel(path4)

# %%
power_jobtype_2021_01.head(12)
# Out:
#        계약종별 전력사용량 월별( 20230321 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0   시도 : 광주광역시, 시군구 : 전체(시 / 군 / 구)        NaN            NaN        NaN
# 1       기간 : 2021년 01 월 ~ 2021년 06월        NaN            NaN        NaN
# 2                                년월         시구            시군구       계약구분
# 3                            202101      광주광역시  전체(시 / 군 / 구)        주택용
# 4                            202101      광주광역시  전체(시 / 군 / 구)        일반용
# 5                            202101      광주광역시  전체(시 / 군 / 구)        교육용
# 6                            202101      광주광역시  전체(시 / 군 / 구)        산업용
# 7                            202101      광주광역시  전체(시 / 군 / 구)        농사용
# 8                            202101      광주광역시  전체(시 / 군 / 구)        가로등
# 9                            202101      광주광역시  전체(시 / 군 / 구)        심 야
# 10                           202102      광주광역시  전체(시 / 군 / 구)        주택용
# 11                           202102      광주광역시  전체(시 / 군 / 구)        일반용
#
#    Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 0         NaN           NaN              NaN            NaN
# 1         NaN           NaN              NaN            NaN
# 2     고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3    386,291   200,924,825   22,352,496,686          111.2
# 4     94,050   278,464,922   36,025,290,206          129.4
# 5        630    32,355,494    3,074,821,310           95.0
# 6      6,402   267,717,054   32,272,757,689          120.5
# 7     12,017    11,148,705      494,595,520           44.4
# 8     47,953     7,885,102      815,183,230          103.4
# 9      5,704    13,368,315      960,768,979           71.9
# 10   386,628   194,943,127   21,209,147,084          108.8
# 11    94,096   262,898,297   34,550,202,881          131.4

# %%
power_jobtype_2021_01.drop(labels=range(0, 3),axis=0,inplace=True)
power_jobtype_2021_07.drop(labels=range(0, 3),axis=0, inplace=True)
power_jobtype_2022_01.drop(labels=range(0, 3),axis=0, inplace=True)
power_jobtype_2022_07.drop(labels=range(0, 3),axis=0, inplace=True)

# %%
power_jobtype_2021_01 = power_jobtype_2021_01.iloc[:42]
power_jobtype_2021_07 = power_jobtype_2021_07.iloc[:42]
power_jobtype_2022_01 = power_jobtype_2022_01.iloc[:42]
power_jobtype_2022_07 = power_jobtype_2022_07.iloc[:42]

# %%
power_jobtype_2022_07
# Out:
#    계약종별 전력사용량 월별( 20230321 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 3                        202207      광주광역시  전체(시 / 군 / 구)        주택용
# 4                        202207      광주광역시  전체(시 / 군 / 구)        일반용
# 5                        202207      광주광역시  전체(시 / 군 / 구)        교육용
# 6                        202207      광주광역시  전체(시 / 군 / 구)        산업용
# 7                        202207      광주광역시  전체(시 / 군 / 구)        농사용
# 8                        202207      광주광역시  전체(시 / 군 / 구)        가로등
# 9                        202207      광주광역시  전체(시 / 군 / 구)        심 야
# 10                       202208      광주광역시  전체(시 / 군 / 구)        주택용
# 11                       202208      광주광역시  전체(시 / 군 / 구)        일반용
# 12                       202208      광주광역시  전체(시 / 군 / 구)        교육용
# 13                       202208      광주광역시  전체(시 / 군 / 구)        산업용
# 14                       202208      광주광역시  전체(시 / 군 / 구)        농사용
# 15                       202208      광주광역시  전체(시 / 군 / 구)        가로등
# 16                       202208      광주광역시  전체(시 / 군 / 구)        심 야
# 17                       202209      광주광역시  전체(시 / 군 / 구)        주택용
# 18                       202209      광주광역시  전체(시 / 군 / 구)        일반용
# 19                       202209      광주광역시  전체(시 / 군 / 구)        교육용
# 20                       202209      광주광역시  전체(시 / 군 / 구)        산업용
# 21                       202209      광주광역시  전체(시 / 군 / 구)        농사용
# 22                       202209      광주광역시  전체(시 / 군 / 구)        가로등
# 23                       202209      광주광역시  전체(시 / 군 / 구)        심 야
# 24                       202210      광주광역시  전체(시 / 군 / 구)        주택용
# 25                       202210      광주광역시  전체(시 / 군 / 구)        일반용
# 26                       202210      광주광역시  전체(시 / 군 / 구)        교육용
# 27                       202210      광주광역시  전체(시 / 군 / 구)        산업용
# 28                       202210      광주광역시  전체(시 / 군 / 구)        농사용
# 29                       202210      광주광역시  전체(시 / 군 / 구)        가로등
# 30                       202210      광주광역시  전체(시 / 군 / 구)        심 야
# 31                       202211      광주광역시  전체(시 / 군 / 구)        주택용
# 32                       202211      광주광역시  전체(시 / 군 / 구)        일반용
# 33                       202211      광주광역시  전체(시 / 군 / 구)        교육용
# 34                       202211      광주광역시  전체(시 / 군 / 구)        산업용
# 35                       202211      광주광역시  전체(시 / 군 / 구)        농사용
# 36                       202211      광주광역시  전체(시 / 군 / 구)        가로등
# 37                       202211      광주광역시  전체(시 / 군 / 구)        심 야
# 38                       202212      광주광역시  전체(시 / 군 / 구)        주택용
# 39                       202212      광주광역시  전체(시 / 군 / 구)        일반용
# 40                       202212      광주광역시  전체(시 / 군 / 구)        교육용
# 41                       202212      광주광역시  전체(시 / 군 / 구)        산업용
# 42                       202212      광주광역시  전체(시 / 군 / 구)        농사용
# 43                       202212      광주광역시  전체(시 / 군 / 구)        가로등
# 44                       202212      광주광역시  전체(시 / 군 / 구)        심 야
#
#    Unnamed: 4    Unnamed: 5       Unnamed: 6 Unnamed: 7
# 3    390,156   215,998,337   26,436,749,057      122.4
# 4     97,555   295,199,044   45,473,210,432      154.0
# 5        630    29,711,525    3,636,090,870      122.4
# 6      6,542   282,528,446   39,470,649,953      139.7
# 7     12,586     6,442,917      408,448,525       63.4
# 8     48,997     5,393,415      730,693,453      135.5
# 9      5,263     3,524,894      285,701,785       81.1
# 10   390,098   256,459,950   31,796,507,010      124.0
# 11    97,912   317,419,045   48,205,742,677      151.9
# 12       629    25,994,225    3,379,535,444      130.0
# 13     6,547   274,886,008   38,533,130,335      140.2
# 14    12,623     8,112,063      499,833,803       61.6
# 15    49,057     5,711,285      756,235,938      132.4
# 16     5,243     3,432,259      288,812,881       84.1
# 17   390,404   221,372,316   26,746,057,475      120.8
# 18    98,178   284,745,728   39,253,696,813      137.9
# 19       629    26,128,585    3,028,754,992      115.9
# 20     6,556   257,990,750   30,942,718,966      119.9
# 21    12,643     7,652,187      485,505,025       63.4
# 22    49,095     6,117,580      783,585,821      128.1
# 23     5,220     2,880,597      244,481,196       84.9
# 24   390,694   174,970,366   20,988,363,178      120.0
# 25    98,543   234,836,871   30,575,427,494      130.2
# 26       629    22,138,785    2,429,503,101      109.7
# 27     6,565   244,040,896   30,459,429,664      124.8
# 28    12,691     6,370,510      439,772,097       69.0
# 29    49,131     6,558,372      828,873,344      126.4
# 30     5,201     2,663,683      225,972,970       84.8
# 31   390,863   172,158,352   21,381,031,336      124.2
# 32    98,756   220,521,174   33,382,687,467      151.4
# 33       629    21,471,834    2,654,181,243      123.6
# 34     6,556   254,434,089   37,212,320,674      146.3
# 35    17,228     9,822,715      613,460,789       62.5
# 36    49,155     7,080,851      906,696,423      128.0
# 37     5,182     5,035,510      430,042,090       85.4
# 38   390,833   180,572,866   22,743,938,979      126.0
# 39    99,014   251,968,761   40,126,199,106      159.3
# 40       629    31,159,967    3,821,817,926      122.7
# 41     6,550   256,259,483   38,670,493,980      150.9
# 42    12,753     8,624,110      597,859,534       69.3
# 43    49,181     7,316,937      919,003,330      125.6
# 44     5,168     8,466,299      792,167,545       93.6

# %%
power_entire = pd.concat([power_jobtype_2021_01,
                                    power_jobtype_2021_07,
                                    power_jobtype_2022_01,
                                    power_jobtype_2022_07])

# %%
power_entire.reset_index(drop=True, inplace=True)

# %%
power_entire.drop(columns='Unnamed: 2', inplace=True)

# %%
power_entire
# Out:
#     계약종별 전력사용량 월별( 20230321 현재 ) Unnamed: 1 Unnamed: 3 Unnamed: 4  \
# 0                         202101      광주광역시        주택용   386,291
# 1                         202101      광주광역시        일반용    94,050
# 2                         202101      광주광역시        교육용       630
# 3                         202101      광주광역시        산업용     6,402
# 4                         202101      광주광역시        농사용    12,017
# ..                           ...        ...        ...        ...
# 163                       202212      광주광역시        교육용       629
# 164                       202212      광주광역시        산업용     6,550
# 165                       202212      광주광역시        농사용    12,753
# 166                       202212      광주광역시        가로등    49,181
# 167                       202212      광주광역시        심 야     5,168
#
#        Unnamed: 5       Unnamed: 6 Unnamed: 7
# 0    200,924,825   22,352,496,686      111.2
# 1    278,464,922   36,025,290,206      129.4
# 2     32,355,494    3,074,821,310       95.0
# 3    267,717,054   32,272,757,689      120.5
# 4     11,148,705      494,595,520       44.4
# ..            ...              ...        ...
# 163   31,159,967    3,821,817,926      122.7
# 164  256,259,483   38,670,493,980      150.9
# 165    8,624,110      597,859,534       69.3
# 166    7,316,937      919,003,330      125.6
# 167    8,466,299      792,167,545       93.6
#
# [168 rows x 7 columns]

# %%
power_entire.rename(columns={'계약종별 전력사용량 월별( 20230321 현재 )':'년도',
                                                       'Unnamed: 1': "시도",
                                                       'Unnamed: 3': "계약구분",
                                                       'Unnamed: 4': "고객수",
                                                       'Unnamed: 5': "사용량(kWh)",
                                                       'Unnamed: 6': "전기요금(원)",
                                                       'Unnamed: 7': "평균판매단가(원/kWh)"}, inplace=True)

# %%
power_entire.head(3)
# Out:
#        년도     시도 계약구분       고객수      사용량(kWh)          전기요금(원) 평균판매단가(원/kWh)
# 0  202101  광주광역시  주택용  386,291   200,924,825   22,352,496,686         111.2
# 1  202101  광주광역시  일반용   94,050   278,464,922   36,025,290,206         129.4
# 2  202101  광주광역시  교육용      630    32,355,494    3,074,821,310          95.0

# %%
power_entire.sort_values('년도',inplace=True)

# %%
power_entire.to_csv('광주_업종별_전력사용량.csv', encoding='cp949')
