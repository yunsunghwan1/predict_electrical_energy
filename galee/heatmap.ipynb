# %%
import pandas as pd
import folium,json
import ipywidgets as widgets
from ipywidgets import interact
import datetime

# %%
heat_12 = pd.read_csv('data\power_demand_mean_month_2012.csv', encoding='cp949')
heat_13 = pd.read_csv('data\power_demand_mean_month_2013.csv', encoding='cp949')
heat_14 = pd.read_csv('data\power_demand_mean_month_2014.csv', encoding='cp949')
heat_15 = pd.read_csv('data\power_demand_mean_month_2015.csv', encoding='cp949')
heat_16 = pd.read_csv('data\power_demand_mean_month_2016.csv', encoding='cp949')
heat_17 = pd.read_csv('data\power_demand_mean_month_2017.csv', encoding='cp949')
heat_18 = pd.read_csv('data\power_demand_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\power_demand_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\power_demand_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\power_demand_mean_month_2021.csv', encoding='cp949')
heat_22 = pd.read_csv('data\power_demand_mean_month_2022.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df =  pd.concat([heat_12, heat_13,heat_14, heat_15,heat_16, heat_17,heat_18, heat_19, heat_20, heat_21, heat_22]).reset_index(drop=True)


data = df.pivot(index='year', columns='month', values='현재수요(MW)').to_numpy()

# Define the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Define the y-axis tick labels (years)
years = df['year'].unique()
fig, ax = plt.subplots()
im = ax.imshow(data, cmap='YlGnBu')

ax.set_xticks(np.arange(len(months)))
ax.set_yticks(np.arange(len(years)))
ax.set_xticklabels(months)
ax.set_yticklabels(years)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Add the data values as annotations to the heatmap
# for i in range(len(years)):
#     for j in range(len(months)):
#         text = ax.text(j, i, data[i, j], ha="center", va="center", color="w")

# Add a colorbar to the heatmap
cbar = ax.figure.colorbar(im, ax=ax)

# Set the title of the plot
ax.set_title("Power Demand (MW)")

# Show the plot
plt.show()

# %%
heat_18 = pd.read_csv('data\sunpower_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\sunpower_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\sunpower_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\sunpower_mean_month_2021.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df =  pd.concat([heat_18, heat_19, heat_20, heat_21]).reset_index(drop=True)


data = df.pivot(index='year', columns='month', values='발전량 ').to_numpy()

# Define the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Define the y-axis tick labels (years)
years = df['year'].unique()
fig, ax = plt.subplots()
im = ax.imshow(data, cmap='YlGnBu')

ax.set_xticks(np.arange(len(months)))
ax.set_yticks(np.arange(len(years)))
ax.set_xticklabels(months)
ax.set_yticklabels(years)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Add the data values as annotations to the heatmap
# for i in range(len(years)):
#     for j in range(len(months)):
#         text = ax.text(j, i, data[i, j], ha="center", va="center", color="w")

# Add a colorbar to the heatmap
cbar = ax.figure.colorbar(im, ax=ax)

# Set the title of the plot
ax.set_title("Power Generation (in kWh)")

# Show the plot
plt.show()

# %%
heat_18 = pd.read_csv('data\sunpower_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\sunpower_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\sunpower_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\sunpower_mean_month_2021.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df = pd.concat([heat_18, heat_19, heat_20, heat_21]).reset_index(drop=True)

# Define the colors for the scatter plot
colors = ['blue', 'orange', 'green', 'red']

# Create a scatter plot for each year
for i, year in enumerate(df['year'].unique()):
    year_data = df[df['year'] == year]
    plt.scatter(year_data['month'], year_data['발전량 '], c=colors[i], label=str(year))

# Set the x-axis and y-axis labels
plt.xlabel('Month')
plt.ylabel('Power Generation (in kWh)')

# Set the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1, 13), months)

# Add a legend to the plot
plt.legend()

# Set the title of the plot
plt.title('Power Generation by Month and Year')

# Show the plot
plt.show()

# %%
heat_12 = pd.read_csv('data\power_demand_mean_month_2012.csv', encoding='cp949')
heat_13 = pd.read_csv('data\power_demand_mean_month_2013.csv', encoding='cp949')
heat_14 = pd.read_csv('data\power_demand_mean_month_2014.csv', encoding='cp949')
heat_15 = pd.read_csv('data\power_demand_mean_month_2015.csv', encoding='cp949')
heat_16 = pd.read_csv('data\power_demand_mean_month_2016.csv', encoding='cp949')
heat_17 = pd.read_csv('data\power_demand_mean_month_2017.csv', encoding='cp949')
heat_18 = pd.read_csv('data\power_demand_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\power_demand_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\power_demand_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\power_demand_mean_month_2021.csv', encoding='cp949')
heat_22 = pd.read_csv('data\power_demand_mean_month_2022.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df =  pd.concat([heat_12, heat_13,heat_14, heat_15,heat_16, heat_17,heat_18, heat_19, heat_20, heat_21, heat_22]).reset_index(drop=True)


# Define the colors for the line plot
# colors = ['blue', 'orange', 'green', 'red', 'black','gray', 'pink','yellow', 'sky', 'purple']

# Create a line plot for each year
for i, year in enumerate(df['year'].unique()):
    year_data = df[df['year'] == year]
    plt.plot(year_data['month'], year_data['현재수요(MW)'], label=str(year))

# Set the x-axis and y-axis labels
plt.xlabel('Month')
plt.ylabel('Power Demand (MW)')

# Set the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1, 13), months)

# Add a legend to the plot
plt.legend()

# Set the title of the plot
plt.title('Power Demand (MW) by Month and Year')

# Show the plot
plt.show()

# %%
heat_18 = pd.read_csv('data\sunpower_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\sunpower_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\sunpower_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\sunpower_mean_month_2021.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df = pd.concat([heat_18, heat_19, heat_20, heat_21]).reset_index(drop=True)

# Define the colors for the line plot
colors = ['blue', 'orange', 'green', 'red']

# Create a line plot for each year
for i, year in enumerate(df['year'].unique()):
    year_data = df[df['year'] == year]
    plt.plot(year_data['month'], year_data['발전량 '], c=colors[i], label=str(year))

# Set the x-axis and y-axis labels
plt.xlabel('Month')
plt.ylabel('Power Generation (in kWh)')

# Set the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1, 13), months)

# Add a legend to the plot
plt.legend()

# Set the title of the plot
plt.title('Power Generation by Month and Year')

# Show the plot
plt.show()

# %%
heat_12 = pd.read_csv('data\weather_data_mean_month_2012.csv', encoding='cp949')
heat_13 = pd.read_csv('data\weather_data_mean_month_2013.csv', encoding='cp949')
heat_14 = pd.read_csv('data\weather_data_mean_month_2014.csv', encoding='cp949')
heat_15 = pd.read_csv('data\weather_data_mean_month_2015.csv', encoding='cp949')
heat_16 = pd.read_csv('data\weather_data_mean_month_2016.csv', encoding='cp949')
heat_17 = pd.read_csv('data\weather_data_mean_month_2017.csv', encoding='cp949')
heat_18 = pd.read_csv('data\weather_data_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\weather_data_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\weather_data_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\weather_data_mean_month_2021.csv', encoding='cp949')
heat_22 = pd.read_csv('data\weather_data_mean_month_2022.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df =  pd.concat([heat_12, heat_13,heat_14, heat_15,heat_16, heat_17,heat_18, heat_19, heat_20, heat_21, heat_22]).reset_index(drop=True)


# Define the colors for the line plot
# colors = ['blue', 'orange', 'green', 'red', 'black','gray', 'pink','yellow', 'sky', 'purple']

# Create a line plot for each year
for i, year in enumerate(df['year'].unique()):
    year_data = df[df['year'] == year]
    plt.plot(year_data['month'], year_data['기온(°C)'], label=str(year))

# Set the x-axis and y-axis labels
plt.xlabel('Month')
plt.ylabel('Power Demand (MW)')

# Set the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1, 13), months)

# Add a legend to the plot
plt.legend()

# Set the title of the plot
plt.title('temp(°C) by Month and Year')

# Show the plot
plt.show()

# %%
heat_12 = pd.read_csv('data\weather_data_mean_month_2012.csv', encoding='cp949')
heat_13 = pd.read_csv('data\weather_data_mean_month_2013.csv', encoding='cp949')
heat_14 = pd.read_csv('data\weather_data_mean_month_2014.csv', encoding='cp949')
heat_15 = pd.read_csv('data\weather_data_mean_month_2015.csv', encoding='cp949')
heat_16 = pd.read_csv('data\weather_data_mean_month_2016.csv', encoding='cp949')
heat_17 = pd.read_csv('data\weather_data_mean_month_2017.csv', encoding='cp949')
heat_18 = pd.read_csv('data\weather_data_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\weather_data_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\weather_data_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\weather_data_mean_month_2021.csv', encoding='cp949')
heat_22 = pd.read_csv('data\weather_data_mean_month_2022.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df =  pd.concat([heat_12, heat_13,heat_14, heat_15,heat_16, heat_17,heat_18, heat_19, heat_20, heat_21, heat_22]).reset_index(drop=True)


# Define the colors for the line plot
# colors = ['blue', 'orange', 'green', 'red', 'black','gray', 'pink','yellow', 'sky', 'purple']

# Create a line plot for each year
for i, year in enumerate(df['year'].unique()):
    year_data = df[df['year'] == year]
    plt.plot(year_data['month'], year_data['풍속(m/s)'], label=str(year))

# Set the x-axis and y-axis labels
plt.xlabel('Month')
plt.ylabel('Power Demand (MW)')

# Set the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1, 13), months)

# Add a legend to the plot
plt.legend()

# Set the title of the plot
plt.title('wind power(m/s) by Month and Year')

# Show the plot
plt.show()

# %%
heat_12 = pd.read_csv('data\weather_data_mean_month_2012.csv', encoding='cp949')
heat_13 = pd.read_csv('data\weather_data_mean_month_2013.csv', encoding='cp949')
heat_14 = pd.read_csv('data\weather_data_mean_month_2014.csv', encoding='cp949')
heat_15 = pd.read_csv('data\weather_data_mean_month_2015.csv', encoding='cp949')
heat_16 = pd.read_csv('data\weather_data_mean_month_2016.csv', encoding='cp949')
heat_17 = pd.read_csv('data\weather_data_mean_month_2017.csv', encoding='cp949')
heat_18 = pd.read_csv('data\weather_data_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\weather_data_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\weather_data_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\weather_data_mean_month_2021.csv', encoding='cp949')
heat_22 = pd.read_csv('data\weather_data_mean_month_2022.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df =  pd.concat([heat_12, heat_13,heat_14, heat_15,heat_16, heat_17,heat_18, heat_19, heat_20, heat_21, heat_22]).reset_index(drop=True)


# Define the colors for the line plot
# colors = ['blue', 'orange', 'green', 'red', 'black','gray', 'pink','yellow', 'sky', 'purple']

# Create a line plot for each year
for i, year in enumerate(df['year'].unique()):
    year_data = df[df['year'] == year]
    plt.plot(year_data['month'], year_data['습도(%)'], label=str(year))

# Set the x-axis and y-axis labels
plt.xlabel('Month')
plt.ylabel('Power Demand (MW)')

# Set the x-axis tick labels (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1, 13), months)

# Add a legend to the plot
plt.legend()

# Set the title of the plot
plt.title('humidity(%) by Month and Year')

# Show the plot
plt.show()

# %%
# heat_12 = pd.read_csv('power_demand_mean_day_data.csv', encoding='cp949')
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.rcParams['figure.figsize'] = [12, 8]

# df =  pd.concat([heat_12]).reset_index(drop=True)

# # df.head(2)

# # Create a line plot for each year
# for i, year in enumerate(df['datetime'].unique()):
#     year_data = df[df['year'] == year]
#     plt.plot(year_data['day'], year_data['현재수요(MW)'], label=str(year))

# # Set the x-axis and y-axis labels
# plt.xlabel('Month')
# plt.ylabel('Power Demand (MW)')

# # Set the x-axis tick labels (months)
# months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# plt.xticks(np.arange(1, 13), months)

# # Add a legend to the plot
# plt.legend()

# # Set the title of the plot
# plt.title('Power Demand (MW) by Day and Year')

# # Show the plot
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\admin\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\Users\admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ...

# %%
# heat_12 = pd.read_csv('power_demand_mean_day_data.csv', encoding='cp949')

# # Extract year from datetime column
# heat_12['year'] = pd.to_datetime(heat_12['datetime']).dt.year

# # Create a pivot table to aggregate mean power demand by year and day
# df_pivot = heat_12.pivot_table(values='현재수요(MW)', index='day', columns='year', aggfunc=np.mean)

# # Create a figure with a grid of subplots
# fig, axs = plt.subplots(nrows=4, ncols=3, figsize=(20, 18), sharex=True, sharey=True)

# # Loop through the years and plot the daily power demand in each subplot
# for i, year in enumerate(df_pivot.columns):
#     row = i // 6
#     col = i % 6
#     ax = axs[row, col]
#     ax.plot(df_pivot.index, df_pivot[year])
#     ax.set_title(str(year))

# # Set the x-axis and y-axis labels
# fig.text(0.5, 0.04, 'Day of Month', ha='center')
# fig.text(0.04, 0.5, 'Power Demand (MW)', va='center', rotation='vertical')

# # Set the title of the plot
# fig.suptitle('Daily Power Demand (MW) by Year')

# # Adjust the layout to prevent overlap of subplot titles
# fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# # Show the plot
# plt.show()

# %%
heat_18 = pd.read_csv('data\sunpower_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\sunpower_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\sunpower_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\sunpower_mean_month_2021.csv', encoding='cp949')
demand_18 = pd.read_csv('data\power_demand_mean_month_2018.csv', encoding='cp949')
demand_19 = pd.read_csv('data\power_demand_mean_month_2019.csv', encoding='cp949')
demand_20 = pd.read_csv('data\power_demand_mean_month_2020.csv', encoding='cp949')
demand_21 = pd.read_csv('data\power_demand_mean_month_2021.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df_heat = pd.concat([heat_18, heat_19, heat_20, heat_21]).reset_index(drop=True)
df_demand = pd.concat([demand_18, demand_19, demand_20, demand_21]).reset_index(drop=True)

df_merged = pd.merge(df_heat, df_demand, on=['year', 'month'])

corr = df_merged['현재수요(MW)'].corr(df_merged['발전량 '])
# Drop unnecessary columns
df_merged.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'], inplace=True)

# Rename columns for better readability
df_merged.rename(columns={'power generation': '발전량 ', 'current demand (MW)': 'demand'}, inplace=True)

plt.scatter(df_merged['현재수요(MW)'], df_merged['발전량 '])

# Add axis labels and title
plt.xlabel('Demand (MW)')
plt.ylabel('Generation (kWh)')
plt.title(f'Correlation between Power Demand and Generation: {corr}')

# Show the plot
plt.show()

# %%
heat_18 = pd.read_csv('data\sunpower_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\sunpower_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\sunpower_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\sunpower_mean_month_2021.csv', encoding='cp949')
weather_18 = pd.read_csv('data\weather_data_mean_month_2018.csv', encoding='cp949')
weather_19 = pd.read_csv('data\weather_data_mean_month_2019.csv', encoding='cp949')
weather_20 = pd.read_csv('data\weather_data_mean_month_2020.csv', encoding='cp949')
weather_21 = pd.read_csv('data\weather_data_mean_month_2021.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df_heat = pd.concat([heat_18, heat_19, heat_20, heat_21]).reset_index(drop=True)
df_weather = pd.concat([weather_18, weather_19, weather_20, weather_21]).reset_index(drop=True)

df_merged = pd.merge(df_heat, df_weather, on=['year', 'month'])

corr = df_merged['기온(°C)'].corr(df_merged['발전량 '])
# Drop unnecessary columns
df_merged.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'], inplace=True)

# Rename columns for better readability
df_merged.rename(columns={'power generation': '발전량 ', 'current temp(°C)': '기온(°C)'}, inplace=True)

plt.scatter(df_merged['기온(°C)'], df_merged['발전량 '])

# Add axis labels and title
plt.xlabel('current temp(°C)')
plt.ylabel('Generation(kWh)')
plt.title(f'Correlation between temp(°C) and Generation: {corr}')
# print(corr)
# Show the plot
plt.show()

# %%
heat_18 = pd.read_csv('data\sunpower_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\sunpower_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\sunpower_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\sunpower_mean_month_2021.csv', encoding='cp949')
weather_18 = pd.read_csv('data\weather_data_mean_month_2018.csv', encoding='cp949')
weather_19 = pd.read_csv('data\weather_data_mean_month_2019.csv', encoding='cp949')
weather_20 = pd.read_csv('data\weather_data_mean_month_2020.csv', encoding='cp949')
weather_21 = pd.read_csv('data\weather_data_mean_month_2021.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df_heat = pd.concat([heat_18, heat_19, heat_20, heat_21]).reset_index(drop=True)
df_weather = pd.concat([weather_18, weather_19, weather_20, weather_21]).reset_index(drop=True)

df_merged = pd.merge(df_heat, df_weather, on=['year', 'month'])

corr = df_merged['풍속(m/s)'].corr(df_merged['발전량 '])
# Drop unnecessary columns
df_merged.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'], inplace=True)

# Rename columns for better readability
df_merged.rename(columns={'power generation': '발전량 ', 'Wind Speed (m/s)': '풍속(m/s)'}, inplace=True)

plt.scatter(df_merged['풍속(m/s)'], df_merged['발전량 '])

# Add axis labels and title
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Generation(kWh)')
plt.title(f'Correlation between Wind Speed (m/s) and Generation: {corr}')
# print(corr)
# Show the plot
plt.show()

# %%
heat_18 = pd.read_csv('data\sunpower_mean_month_2018.csv', encoding='cp949')
heat_19 = pd.read_csv('data\sunpower_mean_month_2019.csv', encoding='cp949')
heat_20 = pd.read_csv('data\sunpower_mean_month_2020.csv', encoding='cp949')
heat_21 = pd.read_csv('data\sunpower_mean_month_2021.csv', encoding='cp949')
weather_18 = pd.read_csv('data\weather_data_mean_month_2018.csv', encoding='cp949')
weather_19 = pd.read_csv('data\weather_data_mean_month_2019.csv', encoding='cp949')
weather_20 = pd.read_csv('data\weather_data_mean_month_2020.csv', encoding='cp949')
weather_21 = pd.read_csv('data\weather_data_mean_month_2021.csv', encoding='cp949')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 8]

df_heat = pd.concat([heat_18, heat_19, heat_20, heat_21]).reset_index(drop=True)
df_weather = pd.concat([weather_18, weather_19, weather_20, weather_21]).reset_index(drop=True)

df_merged = pd.merge(df_heat, df_weather, on=['year', 'month'])

corr = df_merged['습도(%)'].corr(df_merged['발전량 '])
# Drop unnecessary columns
df_merged.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'], inplace=True)

# Rename columns for better readability
df_merged.rename(columns={'power generation': '발전량 ', 'humidity (%)': '습도(%)'}, inplace=True)

plt.scatter(df_merged['습도(%)'], df_merged['발전량 '])

# Add axis labels and title
plt.xlabel('humidity (%)')
plt.ylabel('Generation(kWh)')
plt.title(f'Correlation between humidity (%) and Generation: {corr}')
# print(corr)
# Show the plot
plt.show()
